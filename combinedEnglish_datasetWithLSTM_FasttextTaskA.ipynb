# %%
import numpy as np
import pandas as pd
import sklearn
import nltk
nltk.download('stopwords')
nltk.download('punkt')
from sklearn import feature_extraction,model_selection
from sklearn.metrics import confusion_matrix
import glob
import os
import string
import tensorflow as tf
import keras as K
import zipfile
from itertools import chain
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
import matplotlib.pyplot as plt
from sklearn.metrics import plot_confusion_matrix, classification_report
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#load pre-trained embedding:
zip_ref = zipfile.ZipFile("/content/drive/My Drive/Minor Project/crawl-300d-2M.vec.zip", 'r')
zip_ref.extractall()
zip_ref.close()
embeddings_index = {}
f = open('/content/crawl-300d-2M.vec', encoding="utf8")
for line in f:
    values = line.split()#This splits each values in a  line with spaces
    word = values[0] # This store the first values which is the word in english
    coefs = np.asarray(values[1:], dtype='float32') # This converts all splitted values from 1 to last(expect first word) into an array
    embeddings_index[word] = coefs # english word = array of numerical values
f.close()
print('Total %s word vectors in crawl-300-2M.' % len(embeddings_index))
# Out:
# Total 1999996 word vectors in crawl-300-2M.

# %%
df = pd.read_csv("/content/drive/My Drive/Minor Project/agr_en_dev.csv", names= ['File_ID', 'Text', 'Label'])
df = df.drop(columns=['File_ID'])
df['Label'] = df['Label'].map({'NAG': 0, 'CAG': 1,'OAG': 2})
df.head()
# Out:
#                                                 Text  Label
# 0  The quality of re made now makes me think it i...      1
# 1  @siva \nHow is ur mother???\nHow is ur wife???...      0
# 2  Also see ....hw ur RSS activist caught in Burk...      0
# 3  On the death of 2 jawans in LOC CROSS FIRING\n...      0
# 4  Modi ho ya Manmohan singh saala yeh log kuch n...      2

# %%
df1 = pd.read_csv("/content/drive/My Drive/Minor Project/agr_en_fb_gold.csv", names= ['File_ID', 'Text', 'Label'])
df1 = df1.drop(columns=['File_ID'])
df1['Label'] = df1['Label'].map({'NAG': 0, 'CAG': 1,'OAG': 2})
df1.head()
# Out:
#                                                 Text  Label
# 0  If government of india don't take strict actio...      0
# 1  So now we know. The women should be under the ...      0
# 2  गद्दारो तुमसे ही तो खतरा है अबकी बार साफ हो जाओगे      0
# 3  Do you think markets are gonna be sideways til...      0
# 4  Jago Urjut Jago....\nSave common people from\n...      0

# %%
df2 = pd.read_csv("/content/drive/My Drive/Minor Project/agr_en_train.csv", names= ['File_ID', 'Text', 'Label'])
df2 = df2.drop(columns=['File_ID'])
df2['Label'] = df2['Label'].map({'NAG': 0, 'CAG': 1,'OAG': 2})
df2.head()
# Out:
#                                                 Text  Label
# 0  Well said sonu..you have courage to stand agai...      2
# 1  Most of Private Banks ATM's Like HDFC, ICICI e...      0
# 2     Now question is, Pakistan will adhere to this?      2
# 3  Pakistan is comprised of fake muslims who does...      2
# 4  ??we r against cow slaughter,so of course it w...      0

# %%
df3 = pd.read_csv("/content/drive/My Drive/Minor Project/agr_en_tw_gold.csv", names= ['File_ID', 'Text', 'Label'])
df3 = df3.drop(columns=['File_ID'])
df3['Label'] = df3['Label'].map({'NAG': 0, 'CAG': 1,'OAG': 2})
df3.head()
# Out:
#                                                 Text  Label
# 0  6-0 hahahahahaha har ek pakistani ko yeh pic d...      0
# 1  @sardanarohit :While entire nation is praying ...      2
# 2  shoaib: wahab riaz looks like johnson. kapil d...      0
# 3  ramraj cottons r. ashwin southindian , chennai...      0
# 4  #indvsuae jeet gaye... :) :) cmon starsports n...      0

# %%
df4 = pd.read_csv("/content/drive/My Drive/Minor Project/eng_train.csv")
df4 = df4.drop(columns=['ID', 'Sub-task B'])
df4 = df4.rename(columns={'Sub-task A' : 'Label'})
df4['Label'] = df4['Label'].map({'NAG': 0, 'CAG': 1,'OAG': 2})
df4.tail()
# Out:
#                                                    Text  Label
# 4258  Abey loudey Arnab... Did u ever see the vedios...      2
# 4259  Arundati is very rich where she get money who ...      0
# 4260  People may criticize Pratik Borade by saying t...      1
# 4261                                     @Naaz Sk hello      0
# 4262  We want to read your book sir, please make it ...      0

# %%
frames = [df, df1, df2, df3, df4]
train_df = pd.concat(frames)
train_df
# Out:
#                                                    Text  Label
# 0     The quality of re made now makes me think it i...      1
# 1     @siva \nHow is ur mother???\nHow is ur wife???...      0
# 2     Also see ....hw ur RSS activist caught in Burk...      0
# 3     On the death of 2 jawans in LOC CROSS FIRING\n...      0
# 4     Modi ho ya Manmohan singh saala yeh log kuch n...      2
# ...                                                 ...    ...
# 4258  Abey loudey Arnab... Did u ever see the vedios...      2
# 4259  Arundati is very rich where she get money who ...      0
# 4260  People may criticize Pratik Borade by saying t...      1
# 4261                                     @Naaz Sk hello      0
# 4262  We want to read your book sir, please make it ...      0
#
# [21436 rows x 2 columns]

# %%
test_df = pd.read_csv("/content/drive/My Drive/Minor Project/eng_dev.csv")
test_df = test_df.drop(columns=['ID', 'Sub-task B'])
test_df = test_df.rename(columns={'Sub-task A' : 'Label'})
test_df['Label'] = test_df['Label'].map({'NAG': 0, 'CAG': 1,'OAG': 2})
test_df
# Out:
#                                                    Text  Label
# 0           U deserve more subscribers. U really great.      0
# 1                                        Nice video....      0
# 2     sorry if i bother somebody.. iam a defence asp...      0
# 3     Joker was amazing....it was not glamorised !.....      0
# 4                                             Nice baro      0
# ...                                                 ...    ...
# 1061  Ranu Mandal is third class [woman.No](http://w...      2
# 1062  [15:23](https://www.youtube.com/watch?v=N_ZMfQ...      0
# 1063                              Love u bro keep it up      0
# 1064                                    May I help you?      0
# 1065  You are great sir !!! When a i saw a movie fir...      0
#
# [1066 rows x 2 columns]

# %%
train_df.shape, test_df.shape
# Out:
# ((21436, 2), (1066, 2))

# %%
print(train_df['Label'].value_counts())
print(test_df['Label'].value_counts())
# Out:
# 0    10772
# 1     6305
# 2     4359
# Name: Label, dtype: int64
# 0    836
# 1    117
# 2    113
# Name: Label, dtype: int64

# %%
train_line=train_df['Text'].apply(lambda x: nltk.word_tokenize(x))
dev_line=test_df['Text'].apply(lambda x: nltk.word_tokenize(x))
dev_line,train_line
# Out:
# (0       [U, deserve, more, subscribers, ., U, really, ...
#  1                                   [Nice, video, ..., .]
#  2       [sorry, if, i, bother, somebody.., iam, a, def...
#  3       [Joker, was, amazing, ..., .it, was, not, glam...
#  4                                            [Nice, baro]
#                                ...
#  1061    [Ranu, Mandal, is, third, class, [, woman.No, ...
#  1062    [[, 15:23, ], (, https, :, //www.youtube.com/w...
#  1063                         [Love, u, bro, keep, it, up]
#  1064                               [May, I, help, you, ?]
#  1065    [You, are, great, sir, !, !, !, When, a, i, sa...
#  Name: Text, Length: 1066, dtype: object,
#  0       [The, quality, of, re, made, now, makes, me, t...
#  1       [@, siva, How, is, ur, mother, ?, ?, ?, How, i...
#  2       [Also, see, ..., .hw, ur, RSS, activist, caugh...
#  3       [On, the, death, of, 2, jawans, in, LOC, CROSS...
#  4       [Modi, ho, ya, Manmohan, singh, saala, yeh, lo...
#                                ...
#  4258    [Abey, loudey, Arnab, ..., Did, u, ever, see, ...
#  4259    [Arundati, is, very, rich, where, she, get, mo...
#  4260    [People, may, criticize, Pratik, Borade, by, s...
#  4261                                 [@, Naaz, Sk, hello]
#  4262    [We, want, to, read, your, book, sir, ,, pleas...
#  Name: Text, Length: 21436, dtype: object)

# %%
tk=Tokenizer(lower=True,split=" ")
tk.fit_on_texts(train_line)
word_index=tk.word_index
word_index
# Out:
# {'.': 1,
#  'the': 2,
#  'to': 3,
#  ',': 4,
#  'and': 5,
#  'is': 6,
#  'of': 7,
#  '...': 8,
#  'in': 9,
#  'a': 10,
#  '?': 11,
#  'for': 12,
#  'you': 13,
#  'are': 14,
#  'it': 15,
#  'i': 16,
#  'not': 17,
#  '!': 18,
#  'this': 19,
#  'that': 20,
#  'on': 21,
#  'be': 22,
#  '#': 23,
#  'he': 24,
#  'will': 25,
#  'have': 26,
#  'do': 27,
#  'they': 28,
#  'with': 29,
#  'we': 30,
#  "'s": 31,
#  'india': 32,
#  "n't": 33,
#  'by': 34,
#  'but': 35,
#  'all': 36,
#  ':': 37,
#  'u': 38,
#  'people': 39,
#  'from': 40,
#  'as': 41,
#  'what': 42,
#  'your': 43,
#  'like': 44,
#  'who': 45,
#  'can': 46,
#  'so': 47,
#  'if': 48,
#  'has': 49,
#  'or': 50,
#  'was': 51,
#  'no': 52,
#  'should': 53,
#  ')': 54,
#  'indian': 55,
#  'their': 56,
#  'only': 57,
#  'about': 58,
#  'his': 59,
#  'our': 60,
#  'one': 61,
#  'why': 62,
#  'just': 63,
#  '&': 64,
#  'at': 65,
#  'now': 66,
#  '(': 67,
#  'good': 68,
#  'there': 69,
#  'any': 70,
#  'bjp': 71,
#  'how': 72,
#  'more': 73,
#  'them': 74,
#  'time': 75,
#  '@': 76,
#  'then': 77,
#  'modi': 78,
#  'also': 79,
#  'very': 80,
#  'these': 81,
#  'an': 82,
#  'my': 83,
#  'some': 84,
#  'when': 85,
#  'she': 86,
#  'money': 87,
#  'r': 88,
#  '..': 89,
#  'country': 90,
#  'know': 91,
#  'even': 92,
#  'its': 93,
#  'pakistan': 94,
#  'which': 95,
#  'up': 96,
#  'him': 97,
#  'right': 98,
#  'her': 99,
#  'get': 100,
#  'other': 101,
#  "''": 102,
#  'out': 103,
#  'than': 104,
#  'such': 105,
#  'see': 106,
#  'think': 107,
#  'make': 108,
#  'army': 109,
#  '``': 110,
#  'movie': 111,
#  'many': 112,
#  'did': 113,
#  'shutdownjnu': 114,
#  'n': 115,
#  'me': 116,
#  'against': 117,
#  'were': 118,
#  'after': 119,
#  'please': 120,
#  'want': 121,
#  '-': 122,
#  'need': 123,
#  'ur': 124,
#  'man': 125,
#  'sir': 126,
#  'where': 127,
#  'would': 128,
#  'because': 129,
#  'govt': 130,
#  'been': 131,
#  'us': 132,
#  'does': 133,
#  'take': 134,
#  'go': 135,
#  'am': 136,
#  '%': 137,
#  'every': 138,
#  'being': 139,
#  'well': 140,
#  'great': 141,
#  'same': 142,
#  'news': 143,
#  'government': 144,
#  'give': 145,
#  'come': 146,
#  'much': 147,
#  'love': 148,
#  'world': 149,
#  'media': 150,
#  'never': 151,
#  'first': 152,
#  'too': 153,
#  'muslims': 154,
#  'singh': 155,
#  'pm': 156,
#  'stop': 157,
#  'way': 158,
#  'say': 159,
#  'had': 160,
#  'those': 161,
#  'said': 162,
#  'best': 163,
#  'problem': 164,
#  'day': 165,
#  'work': 166,
#  'party': 167,
#  'religion': 168,
#  'better': 169,
#  'life': 170,
#  'support': 171,
#  'congress': 172,
#  'really': 173,
#  'muslim': 174,
#  'new': 175,
#  'most': 176,
#  'here': 177,
#  'may': 178,
#  'video': 179,
#  'still': 180,
#  'bank': 181,
#  'doing': 182,
#  'without': 183,
#  'back': 184,
#  '2': 185,
#  'let': 186,
#  'years': 187,
#  'wrong': 188,
#  'own': 189,
#  'going': 190,
#  'person': 191,
#  'kabir': 192,
#  'must': 193,
#  'nation': 194,
#  'made': 195,
#  'ca': 196,
#  'http': 197,
#  'dont': 198,
#  'big': 199,
#  'understand': 200,
#  'true': 201,
#  'women': 202,
#  'political': 203,
#  'called': 204,
#  'nothing': 205,
#  'done': 206,
#  'hindu': 207,
#  'before': 208,
#  'always': 209,
#  'shame': 210,
#  'name': 211,
#  'jnu': 212,
#  'black': 213,
#  'poor': 214,
#  'd': 215,
#  'yes': 216,
#  'thing': 217,
#  'keep': 218,
#  'respect': 219,
#  'into': 220,
#  'real': 221,
#  'god': 222,
#  'state': 223,
#  'long': 224,
#  'got': 225,
#  'hai': 226,
#  'killed': 227,
#  'ji': 228,
#  'nice': 229,
#  'indvsuae': 230,
#  'over': 231,
#  'indvspak': 232,
#  'watch': 233,
#  'https': 234,
#  'pak': 235,
#  'could': 236,
#  'review': 237,
#  'anna': 238,
#  "'": 239,
#  '1': 240,
#  '’': 241,
#  'feel': 242,
#  'terrorist': 243,
#  'under': 244,
#  'use': 245,
#  'guys': 246,
#  'bad': 247,
#  'become': 248,
#  'indians': 249,
#  '--': 250,
#  'kashmir': 251,
#  'both': 252,
#  'change': 253,
#  'men': 254,
#  'express': 255,
#  'days': 256,
#  'hindus': 257,
#  'comment': 258,
#  'politics': 259,
#  'hi': 260,
#  'bro': 261,
#  'appeal': 262,
#  'religious': 263,
#  'soldiers': 264,
#  'job': 265,
#  'fatwa': 266,
#  '3': 267,
#  'rss': 268,
#  'start': 269,
#  ';': 270,
#  'again': 271,
#  'today': 272,
#  'minister': 273,
#  'next': 274,
#  'view': 275,
#  'movies': 276,
#  's': 277,
#  'opinion': 278,
#  'police': 279,
#  'national': 280,
#  'making': 281,
#  'tell': 282,
#  'agree': 283,
#  'family': 284,
#  'someone': 285,
#  'live': 286,
#  'look': 287,
#  'happy': 288,
#  'cow': 289,
#  'down': 290,
#  'show': 291,
#  'off': 292,
#  'aap': 293,
#  'action': 294,
#  'given': 295,
#  'etc': 296,
#  'law': 297,
#  'help': 298,
#  'power': 299,
#  'delhi': 300,
#  'ever': 301,
#  'working': 302,
#  'things': 303,
#  'anti': 304,
#  'public': 305,
#  'since': 306,
#  'anything': 307,
#  'human': 308,
#  'market': 309,
#  'something': 310,
#  'china': 311,
#  'between': 312,
#  'hope': 313,
#  'part': 314,
#  'issue': 315,
#  'year': 316,
#  'hahaha': 317,
#  ']': 318,
#  'believe': 319,
#  'lot': 320,
#  '4': 321,
#  'ki': 322,
#  'dear': 323,
#  'old': 324,
#  'mr': 325,
#  'few': 326,
#  'others': 327,
#  'last': 328,
#  'fake': 329,
#  'side': 330,
#  'already': 331,
#  'bollywood': 332,
#  'free': 333,
#  'kill': 334,
#  'kind': 335,
#  'buy': 336,
#  'everyone': 337,
#  'place': 338,
#  'saying': 339,
#  'film': 340,
#  'parties': 341,
#  'two': 342,
#  'tax': 343,
#  'hard': 344,
#  'getting': 345,
#  'common': 346,
#  'while': 347,
#  'stupid': 348,
#  'ask': 349,
#  'ha': 350,
#  'high': 351,
#  'expect': 352,
#  'trying': 353,
#  'during': 354,
#  'speak': 355,
#  'kejriwal': 356,
#  '[': 357,
#  '5': 358,
#  'home': 359,
#  'hate': 360,
#  'talk': 361,
#  'point': 362,
#  'giving': 363,
#  'guy': 364,
#  'times': 365,
#  'case': 366,
#  'girl': 367,
#  'put': 368,
#  'taken': 369,
#  'killing': 370,
#  'tv': 371,
#  'bhai': 372,
#  'proud': 373,
#  'business': 374,
#  'election': 375,
#  'sad': 376,
#  'try': 377,
#  'through': 378,
#  'reason': 379,
#  'ppl': 380,
#  'talking': 381,
#  'pakistani': 382,
#  'face': 383,
#  'instead': 384,
#  'everything': 385,
#  'system': 386,
#  'till': 387,
#  'lol': 388,
#  'war': 389,
#  'countries': 390,
#  'legal': 391,
#  'corruption': 392,
#  'another': 393,
#  'call': 394,
#  'move': 395,
#  '10': 396,
#  'due': 397,
#  'strike': 398,
#  'living': 399,
#  'beef': 400,
#  'future': 401,
#  'mind': 402,
#  'per': 403,
#  "'m": 404,
#  'b': 405,
#  'enough': 406,
#  'court': 407,
#  'used': 408,
#  'anyone': 409,
#  'seen': 410,
#  'surgical': 411,
#  'lost': 412,
#  'plz': 413,
#  'kerala': 414,
#  'politicians': 415,
#  'president': 416,
#  'says': 417,
#  'ko': 418,
#  'cash': 419,
#  'find': 420,
#  'else': 421,
#  'm': 422,
#  'pls': 423,
#  'y': 424,
#  'words': 425,
#  'having': 426,
#  'eat': 427,
#  'watching': 428,
#  'thanks': 429,
#  'islam': 430,
#  'sorry': 431,
#  'comments': 432,
#  '“': 433,
#  '”': 434,
#  'act': 435,
#  'mr.': 436,
#  'left': 437,
#  'whole': 438,
#  'character': 439,
#  'means': 440,
#  'sonu': 441,
#  'decision': 442,
#  'matter': 443,
#  'level': 444,
#  'ban': 445,
#  'needs': 446,
#  '100': 447,
#  'term': 448,
#  'khan': 449,
#  'rs': 450,
#  'mean': 451,
#  'taking': 452,
#  'innocent': 453,
#  'thought': 454,
#  'end': 455,
#  'sure': 456,
#  'freedom': 457,
#  'gandhi': 458,
#  'woman': 459,
#  'cm': 460,
#  '//': 461,
#  'actually': 462,
#  '$': 463,
#  'vote': 464,
#  'present': 465,
#  'share': 466,
#  'win': 467,
#  'different': 468,
#  'read': 469,
#  'nd': 470,
#  'father': 471,
#  'peace': 472,
#  "'re": 473,
#  'economy': 474,
#  'behind': 475,
#  'sonia': 476,
#  'channel': 477,
#  'care': 478,
#  'hell': 479,
#  'leader': 480,
#  'truth': 481,
#  'around': 482,
#  'comes': 483,
#  'question': 484,
#  'happen': 485,
#  'society': 486,
#  'difference': 487,
#  'team': 488,
#  'ka': 489,
#  'each': 490,
#  'bring': 491,
#  'rather': 492,
#  'thank': 493,
#  'post': 494,
#  'join': 495,
#  'play': 496,
#  'story': 497,
#  'students': 498,
#  'feminism': 499,
#  'totally': 500,
#  'wants': 501,
#  'issues': 502,
#  'mother': 503,
#  'social': 504,
#  'soon': 505,
#  'banks': 506,
#  'leave': 507,
#  'statement': 508,
#  'na': 509,
#  'started': 510,
#  'terrorists': 511,
#  'pay': 512,
#  'corrupt': 513,
#  'full': 514,
#  'anuj': 515,
#  'coming': 516,
#  'earn': 517,
#  'number': 518,
#  'less': 519,
#  'body': 520,
#  'leaders': 521,
#  '/': 522,
#  't': 523,
#  'check': 524,
#  'wait': 525,
#  'step': 526,
#  'k': 527,
#  'wo': 528,
#  'send': 529,
#  'trump': 530,
#  'wife': 531,
#  'nifty': 532,
#  'far': 533,
#  'journalists': 534,
#  'follow': 535,
#  'happened': 536,
#  'states': 537,
#  'kumar': 538,
#  'speech': 539,
#  'h': 540,
#  '>': 541,
#  '😂': 542,
#  'bike': 543,
#  'cwc15': 544,
#  'once': 545,
#  'company': 546,
#  'paid': 547,
#  'attack': 548,
#  'open': 549,
#  'proper': 550,
#  'away': 551,
#  '…': 552,
#  'towards': 553,
#  'happening': 554,
#  'control': 555,
#  'rule': 556,
#  'turkey': 557,
#  'views': 558,
#  'cant': 559,
#  'non': 560,
#  'least': 561,
#  'tata': 562,
#  'word': 563,
#  'community': 564,
#  'ke': 565,
#  'type': 566,
#  'able': 567,
#  'fact': 568,
#  '<': 569,
#  'stock': 570,
#  'secular': 571,
#  'worst': 572,
#  'waiting': 573,
#  'yet': 574,
#  'sector': 575,
#  'v': 576,
#  'seems': 577,
#  'elections': 578,
#  'stand': 579,
#  'forces': 580,
#  'daily': 581,
#  'lady': 582,
#  'terrorism': 583,
#  'might': 584,
#  'order': 585,
#  'thinking': 586,
#  'using': 587,
#  'idea': 588,
#  'hazare': 589,
#  '=': 590,
#  'bodies': 591,
#  'land': 592,
#  'cnbc': 593,
#  'took': 594,
#  'single': 595,
#  'shows': 596,
#  'came': 597,
#  'fight': 598,
#  'knows': 599,
#  'service': 600,
#  '50': 601,
#  'population': 602,
#  'situation': 603,
#  'rights': 604,
#  'abt': 605,
#  'blame': 606,
#  'choice': 607,
#  'write': 608,
#  'history': 609,
#  'justice': 610,
#  'roy': 611,
#  'brother': 612,
#  'correct': 613,
#  'sense': 614,
#  'islamic': 615,
#  'prime': 616,
#  'water': 617,
#  'price': 618,
#  'modiji': 619,
#  'learn': 620,
#  'save': 621,
#  'majority': 622,
#  'sell': 623,
#  'notes': 624,
#  'development': 625,
#  'feminist': 626,
#  'makes': 627,
#  'continue': 628,
#  'stay': 629,
#  'simple': 630,
#  'request': 631,
#  'speaking': 632,
#  'bloody': 633,
#  'biggest': 634,
#  'according': 635,
#  'strong': 636,
#  'feminists': 637,
#  'secularism': 638,
#  'class': 639,
#  'past': 640,
#  'nigam': 641,
#  'shut': 642,
#  'industry': 643,
#  'top': 644,
#  'create': 645,
#  'cows': 646,
#  'gone': 647,
#  'education': 648,
#  'important': 649,
#  'house': 650,
#  'gave': 651,
#  'noise': 652,
#  'wow': 653,
#  'forget': 654,
#  'run': 655,
#  'ok': 656,
#  'yogi': 657,
#  'terror': 658,
#  'thats': 659,
#  'awesome': 660,
#  'mouth': 661,
#  'remember': 662,
#  'allowed': 663,
#  'wish': 664,
#  'small': 665,
#  'went': 666,
#  'ho': 667,
#  'rest': 668,
#  'self': 669,
#  'se': 670,
#  'death': 671,
#  'based': 672,
#  'p': 673,
#  'mistake': 674,
#  '2017': 675,
#  'accept': 676,
#  'signed': 677,
#  'rahul': 678,
#  'friends': 679,
#  'rbi': 680,
#  'singer': 681,
#  'yourself': 682,
#  'huge': 683,
#  'otherwise': 684,
#  'idiot': 685,
#  'looks': 686,
#  'showing': 687,
#  'group': 688,
#  'copy': 689,
#  'nonsense': 690,
#  'absolutely': 691,
#  'standwithjnu': 692,
#  'liberals': 693,
#  'goes': 694,
#  'oh': 695,
#  'south': 696,
#  'hand': 697,
#  'line': 698,
#  'whether': 699,
#  'arundhati': 700,
#  'serious': 701,
#  'violence': 702,
#  'stocks': 703,
#  'form': 704,
#  'nahi': 705,
#  'clear': 706,
#  'coz': 707,
#  'border': 708,
#  'drama': 709,
#  'crores': 710,
#  'atleast': 711,
#  'reality': 712,
#  'problems': 713,
#  'food': 714,
#  'acting': 715,
#  'isis': 716,
#  'research': 717,
#  'manner': 718,
#  'personal': 719,
#  'false': 720,
#  'created': 721,
#  'kids': 722,
#  'reply': 723,
#  'opposition': 724,
#  'possible': 725,
#  '7': 726,
#  'current': 727,
#  'growth': 728,
#  'whatever': 729,
#  'suffering': 730,
#  'seriously': 731,
#  'policy': 732,
#  'hold': 733,
#  'banned': 734,
#  'investment': 735,
#  'bhi': 736,
#  'cut': 737,
#  'match': 738,
#  'azaan': 739,
#  'month': 740,
#  'citizens': 741,
#  'months': 742,
#  'looking': 743,
#  'above': 744,
#  'card': 745,
#  'culture': 746,
#  'uae': 747,
#  'children': 748,
#  'crime': 749,
#  'ndtv': 750,
#  'hv': 751,
#  'sex': 752,
#  'gay': 753,
#  'salute': 754,
#  'kashmiri': 755,
#  'though': 756,
#  '18': 757,
#  'amount': 758,
#  'jio': 759,
#  'vs': 760,
#  'fool': 761,
#  'demonetization': 762,
#  'english': 763,
#  'soldier': 764,
#  "'ll": 765,
#  'won': 766,
#  'central': 767,
#  'failed': 768,
#  'completely': 769,
#  'negative': 770,
#  'security': 771,
#  'aur': 772,
#  'companies': 773,
#  'supporting': 774,
#  'entire': 775,
#  'loc': 776,
#  'chance': 777,
#  '15': 778,
#  'late': 779,
#  'dog': 780,
#  'deserve': 781,
#  'morning': 782,
#  'azan': 783,
#  'lokpal': 784,
#  '6': 785,
#  'note': 786,
#  'short': 787,
#  'rate': 788,
#  'within': 789,
#  'ye': 790,
#  'heard': 791,
#  'practices': 792,
#  'responsible': 793,
#  'idiots': 794,
#  'democracy': 795,
#  'either': 796,
#  'basis': 797,
#  'proof': 798,
#  'currency': 799,
#  'mutilated': 800,
#  'value': 801,
#  'useless': 802,
#  'headlines': 803,
#  'unable': 804,
#  'whereas': 805,
#  'loudspeakers': 806,
#  'laws': 807,
#  'guess': 808,
#  'launch': 809,
#  'answer': 810,
#  'shown': 811,
#  'playing': 812,
#  'language': 813,
#  'fighting': 814,
#  'communal': 815,
#  'almost': 816,
#  'usa': 817,
#  'hit': 818,
#  'main': 819,
#  'girls': 820,
#  'born': 821,
#  'bajaj': 822,
#  'finally': 823,
#  'loud': 824,
#  'joker': 825,
#  'shahid': 826,
#  'agent': 827,
#  'religions': 828,
#  'bengal': 829,
#  'honest': 830,
#  'husband': 831,
#  'bot': 832,
#  'america': 833,
#  'events': 834,
#  'upcoming': 835,
#  'die': 836,
#  'interest': 837,
#  'target': 838,
#  'watched': 839,
#  'debate': 840,
#  'waste': 841,
#  'c': 842,
#  'hero': 843,
#  'told': 844,
#  'humanity': 845,
#  'became': 846,
#  'constitution': 847,
#  'attention': 848,
#  'hatred': 849,
#  'heart': 850,
#  'voice': 851,
#  'politician': 852,
#  'report': 853,
#  'including': 854,
#  'billion': 855,
#  'bt': 856,
#  'marriage': 857,
#  'champcash': 858,
#  'kya': 859,
#  'road': 860,
#  'bill': 861,
#  'ready': 862,
#  'middle': 863,
#  'brain': 864,
#  'discussed': 865,
#  'dead': 866,
#  'gets': 867,
#  'fire': 868,
#  'yeah': 869,
#  'arnab': 870,
#  'economic': 871,
#  'kohli': 872,
#  'pratik': 873,
#  'nobody': 874,
#  'book': 875,
#  'parliament': 876,
#  'themselves': 877,
#  'child': 878,
#  'prepared': 879,
#  'investigation': 880,
#  'cr': 881,
#  'low': 882,
#  'reddy': 883,
#  'wonder': 884,
#  'total': 885,
#  'silent': 886,
#  'rt': 887,
#  'super': 888,
#  'shall': 889,
#  'issued': 890,
#  'presented': 891,
#  'temple': 892,
#  '500': 893,
#  'wat': 894,
#  'fan': 895,
#  'o': 896,
#  'supreme': 897,
#  'arjun': 898,
#  '//www.youtube.com/watch': 899,
#  'cheap': 900,
#  'animals': 901,
#  'dogs': 902,
#  'until': 903,
#  'demonetisation': 904,
#  'budget': 905,
#  'income': 906,
#  'except': 907,
#  '20': 908,
#  'force': 909,
#  'knowledge': 910,
#  'protect': 911,
#  'trust': 912,
#  '2016': 913,
#  'university': 914,
#  'needed': 915,
#  'game': 916,
#  'rich': 917,
#  'prove': 918,
#  'online': 919,
#  'asked': 920,
#  'message': 921,
#  'appreciate': 922,
#  'gdp': 923,
#  'publicity': 924,
#  'hours': 925,
#  'information': 926,
#  'together': 927,
#  'speed': 928,
#  'qualified': 929,
#  'grounds': 930,
#  'boss': 931,
#  'illegal': 932,
#  'busy': 933,
#  'boy': 934,
#  'found': 935,
#  'youth': 936,
#  'lives': 937,
#  'fall': 938,
#  'members': 939,
#  'happens': 940,
#  'hear': 941,
#  'merit': 942,
#  'suffer': 943,
#  'listen': 944,
#  'maybe': 945,
#  'further': 946,
#  'nor': 947,
#  'lakh': 948,
#  'rape': 949,
#  'educated': 950,
#  'teach': 951,
#  'example': 952,
#  'eating': 953,
#  'cost': 954,
#  'friend': 955,
#  'dude': 956,
#  'cause': 957,
#  'equal': 958,
#  'hands': 959,
#  'liberal': 960,
#  'remain': 961,
#  'bhakts': 962,
#  'digital': 963,
#  'young': 964,
#  'pain': 965,
#  'crore': 966,
#  'article': 967,
#  'performance': 968,
#  'global': 969,
#  'ya': 970,
#  'results': 971,
#  'meat': 972,
#  'enjoy': 973,
#  'gives': 974,
#  'data': 975,
#  'result': 976,
#  'wanted': 977,
#  'saw': 978,
#  'exactly': 979,
#  'install': 980,
#  'sleep': 981,
#  'car': 982,
#  'criminal': 983,
#  'white': 984,
#  'head': 985,
#  'lead': 986,
#  '💢': 987,
#  'ranu': 988,
#  'enter': 989,
#  'whatsapp': 990,
#  '2000': 991,
#  'generation': 992,
#  'itself': 993,
#  'guidelines': 994,
#  'north': 995,
#  'among': 996,
#  'involved': 997,
#  'allow': 998,
#  '46': 999,
#  'apology': 1000,
#  ...}

# %%
import math
length=math.ceil(np.average(train_line.apply(lambda x:len(x))))
length
# Out:
# 26

# %%
def encode_text(tokenizer, lines, length):
  encoded = tokenizer.texts_to_sequences(lines)
  padded = pad_sequences(encoded, maxlen=length, padding='post')
  return padded

# %%
train_x=encode_text(tk,train_line,length)
print(train_x)
dev_x=encode_text(tk,dev_line,length)
print(dev_x)
# Out:
# [[    2  1082     7 ...     0     0     0]
#  [    6   124   503 ...  1391     8 15550]
#  [   79   106     8 ...     0     0     0]
#  ...
#  [    1 37725    53 ... 37726   457    18]
#  [   76 37727  9269 ...     0     0     0]
#  [   30   121     3 ...     0     0     0]]
# [[   38   781    73 ...     0     0     0]
#  [  229   179     8 ...     0     0     0]
#  [ 1041     7  4076 ... 11637    69     8]
#  ...
#  [  148    38   261 ...     0     0     0]
#  [  178    16   298 ...     0     0     0]
#  [   13    14   141 ...     0     0     0]]

# %%
vocab_size = len(tk.word_index)
print(vocab_size)
# Out:
# 37727

# %%
from keras.utils.np_utils import to_categorical
y_train = to_categorical(np.asarray(train_df['Label']))
y_test = to_categorical(np.asarray(test_df['Label']))
# y_train=np.array(train_df['Sub-task A'])
# y_dev=np.array(dev_df['Sub-task A'])
print(y_train.shape, y_test.shape)
# Out:
# (21436, 3) (1066, 3)

# %%
# Initialize the weight for each word for the embedding layer. Words not present
# in the dictionary initialized by random value 
EMBEDDING_DIM = 300
embedding_matrix = np.random.random((len(word_index) + 1, EMBEDDING_DIM))
#embedding_matrix = (10370, 300) NOTE: It is from uniques words in our tweets
for word, i in word_index.items(): # Selecting word from our tweet unique words list for changing with the values from glove
    embedding_vector = embeddings_index.get(word) # Finding our tweet words in glove and taking its array of 100 values
    if embedding_vector is not None: 
#words not found in embedding index will be all-zeros.
        embedding_matrix[i] = embedding_vector

# %%
from keras.utils.vis_utils import plot_model
from keras.models import Sequential
from keras.layers import Input,LSTM
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Dropout
from keras.layers import Embedding
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
model=Sequential()
model.add(Embedding(vocab_size,100,input_length=train_x.shape[1]))
model.add(LSTM(192, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(3,activation='softmax'))
model.compile(loss = 'categorical_crossentropy', optimizer='adam',metrics = ['accuracy'])
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 26, 100)           3772700
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 192)               225024
# _________________________________________________________________
# dense_4 (Dense)              (None, 3)                 579
# =================================================================
# Total params: 3,998,303
# Trainable params: 3,998,303
# Non-trainable params: 0
# _________________________________________________________________

# %%
history=model.fit(train_x, y_train, validation_data = (dev_x, y_test),epochs=50,batch_size=100, verbose=2)
# Out:
# Train on 21436 samples, validate on 1066 samples
# Epoch 1/50
#  - 17s - loss: 0.9362 - acc: 0.5429 - val_loss: 0.6035 - val_acc: 0.7355
# Epoch 2/50
#  - 16s - loss: 0.7578 - acc: 0.6490 - val_loss: 0.6424 - val_acc: 0.7270
# Epoch 3/50
#  - 16s - loss: 0.6227 - acc: 0.7295 - val_loss: 0.6661 - val_acc: 0.7195
# Epoch 4/50
#  - 16s - loss: 0.4999 - acc: 0.8005 - val_loss: 0.6907 - val_acc: 0.7214
# Epoch 5/50
#  - 16s - loss: 0.3789 - acc: 0.8617 - val_loss: 0.6702 - val_acc: 0.7467
# Epoch 6/50
#  - 16s - loss: 0.3013 - acc: 0.8928 - val_loss: 0.8155 - val_acc: 0.7317
# Epoch 7/50
#  - 15s - loss: 0.2446 - acc: 0.9149 - val_loss: 0.7875 - val_acc: 0.7561
# Epoch 8/50
#  - 16s - loss: 0.2072 - acc: 0.9289 - val_loss: 0.8314 - val_acc: 0.7289
# Epoch 9/50
#  - 16s - loss: 0.1733 - acc: 0.9384 - val_loss: 0.9690 - val_acc: 0.7486
# Epoch 10/50
#  - 16s - loss: 0.1550 - acc: 0.9438 - val_loss: 1.0960 - val_acc: 0.7289
# Epoch 11/50
#  - 16s - loss: 0.1371 - acc: 0.9519 - val_loss: 1.1777 - val_acc: 0.7176
# Epoch 12/50
#  - 16s - loss: 0.1244 - acc: 0.9547 - val_loss: 1.2934 - val_acc: 0.7008
# Epoch 13/50
#  - 16s - loss: 0.1157 - acc: 0.9581 - val_loss: 1.1991 - val_acc: 0.7233
# Epoch 14/50
#  - 16s - loss: 0.1035 - acc: 0.9643 - val_loss: 1.3847 - val_acc: 0.7026
# Epoch 15/50
#  - 16s - loss: 0.1011 - acc: 0.9629 - val_loss: 1.2804 - val_acc: 0.7120
# Epoch 16/50
#  - 16s - loss: 0.0925 - acc: 0.9659 - val_loss: 1.2891 - val_acc: 0.7054
# Epoch 17/50
#  - 16s - loss: 0.0873 - acc: 0.9683 - val_loss: 1.4310 - val_acc: 0.7298
# Epoch 18/50
#  - 16s - loss: 0.0832 - acc: 0.9704 - val_loss: 1.3342 - val_acc: 0.7214
# Epoch 19/50
#  - 16s - loss: 0.0736 - acc: 0.9726 - val_loss: 1.4810 - val_acc: 0.7092
# Epoch 20/50
#  - 16s - loss: 0.0687 - acc: 0.9754 - val_loss: 1.4408 - val_acc: 0.7298
# Epoch 21/50
#  - 16s - loss: 0.0638 - acc: 0.9769 - val_loss: 1.6789 - val_acc: 0.6904
# Epoch 22/50
#  - 16s - loss: 0.0647 - acc: 0.9758 - val_loss: 1.4251 - val_acc: 0.7129
# Epoch 23/50
#  - 15s - loss: 0.0615 - acc: 0.9778 - val_loss: 1.5211 - val_acc: 0.7205
# Epoch 24/50
#  - 16s - loss: 0.0600 - acc: 0.9769 - val_loss: 1.5699 - val_acc: 0.7111
# Epoch 25/50
#  - 16s - loss: 0.0546 - acc: 0.9803 - val_loss: 1.6415 - val_acc: 0.6904
# Epoch 26/50
#  - 15s - loss: 0.0534 - acc: 0.9797 - val_loss: 1.6558 - val_acc: 0.7205
# Epoch 27/50
#  - 16s - loss: 0.0530 - acc: 0.9796 - val_loss: 1.7012 - val_acc: 0.7176
# Epoch 28/50
#  - 16s - loss: 0.0469 - acc: 0.9821 - val_loss: 1.9049 - val_acc: 0.6792
# Epoch 29/50
#  - 16s - loss: 0.0478 - acc: 0.9821 - val_loss: 1.6923 - val_acc: 0.7008
# Epoch 30/50
#  - 16s - loss: 0.0449 - acc: 0.9818 - val_loss: 1.6822 - val_acc: 0.7120
# Epoch 31/50
#  - 16s - loss: 0.0423 - acc: 0.9830 - val_loss: 1.8456 - val_acc: 0.6932
# Epoch 32/50
#  - 16s - loss: 0.0394 - acc: 0.9839 - val_loss: 1.8589 - val_acc: 0.7129
# Epoch 33/50
#  - 16s - loss: 0.0414 - acc: 0.9837 - val_loss: 1.8543 - val_acc: 0.7073
# Epoch 34/50
#  - 17s - loss: 0.0430 - acc: 0.9820 - val_loss: 1.6600 - val_acc: 0.7148
# Epoch 35/50
#  - 16s - loss: 0.0420 - acc: 0.9832 - val_loss: 1.8236 - val_acc: 0.7167
# Epoch 36/50
#  - 16s - loss: 0.0364 - acc: 0.9852 - val_loss: 1.8543 - val_acc: 0.7158
# Epoch 37/50
#  - 16s - loss: 0.0357 - acc: 0.9857 - val_loss: 1.8328 - val_acc: 0.7111
# Epoch 38/50
#  - 16s - loss: 0.0388 - acc: 0.9846 - val_loss: 1.9037 - val_acc: 0.7083
# Epoch 39/50
#  - 16s - loss: 0.0336 - acc: 0.9857 - val_loss: 1.9322 - val_acc: 0.6895
# Epoch 40/50
#  - 16s - loss: 0.0362 - acc: 0.9853 - val_loss: 1.9965 - val_acc: 0.7026
# Epoch 41/50
#  - 16s - loss: 0.0359 - acc: 0.9845 - val_loss: 2.0142 - val_acc: 0.6970
# Epoch 42/50
#  - 16s - loss: 0.0334 - acc: 0.9866 - val_loss: 2.1020 - val_acc: 0.6886
# Epoch 43/50
#  - 16s - loss: 0.0314 - acc: 0.9868 - val_loss: 2.1002 - val_acc: 0.7120
# Epoch 44/50
#  - 16s - loss: 0.0316 - acc: 0.9865 - val_loss: 2.0141 - val_acc: 0.6989
# Epoch 45/50
#  - 16s - loss: 0.0276 - acc: 0.9876 - val_loss: 2.0423 - val_acc: 0.6886
# Epoch 46/50
#  - 16s - loss: 0.0308 - acc: 0.9871 - val_loss: 1.9711 - val_acc: 0.7129
# Epoch 47/50
#  - 16s - loss: 0.0279 - acc: 0.9871 - val_loss: 2.1811 - val_acc: 0.7036
# Epoch 48/50
#  - 17s - loss: 0.0301 - acc: 0.9866 - val_loss: 2.1509 - val_acc: 0.7045
# Epoch 49/50
#  - 16s - loss: 0.0308 - acc: 0.9861 - val_loss: 2.1051 - val_acc: 0.7205
# Epoch 50/50
#  - 16s - loss: 0.0290 - acc: 0.9875 - val_loss: 1.8618 - val_acc: 0.7167

# %%
training_loss=history.history['loss']
validation_loss=history.history['val_loss']
epoch_count=range(1,len(training_loss)+1)
plt.plot(epoch_count, training_loss, 'r--')
plt.plot(epoch_count, validation_loss, 'b-')
plt.legend(['Training Loss', 'Validation Loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
scores = model.evaluate(dev_x, y_test, verbose=0)
print(scores)
# Out:
# [1.8618277581950289, 0.7166979363219599]

# %%
predictions_test = model.predict(dev_x)
print(predictions_test)
# Out:
# [[5.4044634e-01 4.5897880e-01 5.7484442e-04]
#  [9.9994171e-01 3.3822183e-05 2.4450230e-05]
#  [9.8833394e-01 1.1010598e-02 6.5540941e-04]
#  ...
#  [9.9997973e-01 4.9159594e-06 1.5336193e-05]
#  [9.9985683e-01 7.3703224e-05 6.9434238e-05]
#  [9.9784017e-01 2.0610183e-03 9.8838231e-05]]

# %%
predictions_test1 = np.zeros_like(predictions_test)
predictions_test1[np.arange(len(predictions_test)), predictions_test.argmax(1)] = 1

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,predictions_test1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.82      0.84       836
#            1       0.26      0.33      0.29       117
#            2       0.35      0.37      0.36       113
#
#    micro avg       0.72      0.72      0.72      1066
#    macro avg       0.49      0.51      0.50      1066
# weighted avg       0.74      0.72      0.73      1066
#  samples avg       0.72      0.72      0.72      1066
