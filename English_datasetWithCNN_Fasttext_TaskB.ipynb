# %%
import numpy as np
import pandas as pd
import sklearn
import nltk
# from nltk.stem.porter import PorterStemmer
nltk.download('punkt')
from sklearn import feature_extraction,model_selection
from sklearn.metrics import confusion_matrix
import glob
import os
import string
import tensorflow as tf
import keras as K
import zipfile
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
import matplotlib.pyplot as plt
from sklearn.metrics import plot_confusion_matrix
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
def load_csv(path):
  df=pd.read_csv(path).drop(['Sub-task A','ID'],axis=1)
  df=df[(df['Sub-task B']=="NGEN")|(df['Sub-task B']=='GEN')].dropna()
  df['Sub-task B']=(df['Sub-task B']=='GEN').astype(int)
  return df

# %%
train_df=load_csv("/content/drive/My Drive/Colab Notebooks/eng_train.csv")
dev_df=load_csv('/content/drive/My Drive/Colab Notebooks/eng_dev.csv')
print(train_df.head())
print(dev_df.head())
# Out:
#                                                 Text  Sub-task B
# 0                                          Next part           0
# 1                 Iii8mllllllm\nMdxfvb8o90lplppi0005           0
# 2  🤣🤣😂😂🤣🤣🤣😂osm vedio ....keep it up...make more v...           0
# 3  What the fuck was this? I respect shwetabh and...           0
# 4  Concerned authorities should bring arundathi R...           0
#                                                 Text  Sub-task B
# 0        U deserve more subscribers. U really great.           0
# 1                                     Nice video....           0
# 2  sorry if i bother somebody.. iam a defence asp...           1
# 3  Joker was amazing....it was not glamorised !.....           0
# 4                                          Nice baro           0

# %%
train_df.shape,dev_df.shape
# Out:
# ((4263, 2), (1066, 2))

# %%
print(train_df['Sub-task B'].value_counts())
print(dev_df['Sub-task B'].value_counts())
# Out:
# 0    3954
# 1     309
# Name: Sub-task B, dtype: int64
# 0    993
# 1     73
# Name: Sub-task B, dtype: int64

# %%
print(309/4263*100)
print(73/1066*100)
# Out:
# 7.248416608022519
# 6.848030018761726

# %%
train_line=train_df['Text'].apply(lambda x: nltk.word_tokenize(x))
dev_line=dev_df['Text'].apply(lambda x: nltk.word_tokenize(x))
dev_line,train_line
# Out:
# (0       [U, deserve, more, subscribers, ., U, really, ...
#  1                                   [Nice, video, ..., .]
#  2       [sorry, if, i, bother, somebody.., iam, a, def...
#  3       [Joker, was, amazing, ..., .it, was, not, glam...
#  4                                            [Nice, baro]
#                                ...
#  1061    [Ranu, Mandal, is, third, class, [, woman.No, ...
#  1062    [[, 15:23, ], (, https, :, //www.youtube.com/w...
#  1063                         [Love, u, bro, keep, it, up]
#  1064                               [May, I, help, you, ?]
#  1065    [You, are, great, sir, !, !, !, When, a, i, sa...
#  Name: Text, Length: 1066, dtype: object,
#  0                                            [Next, part]
#  1                    [Iii8mllllllm, Mdxfvb8o90lplppi0005]
#  2       [🤣🤣😂😂🤣🤣🤣😂osm, vedio, ..., .keep, it, up, ..., ...
#  3       [What, the, fuck, was, this, ?, I, respect, sh...
#  4       [Concerned, authorities, should, bring, arunda...
#                                ...
#  4258    [Abey, loudey, Arnab, ..., Did, u, ever, see, ...
#  4259    [Arundati, is, very, rich, where, she, get, mo...
#  4260    [People, may, criticize, Pratik, Borade, by, s...
#  4261                                 [@, Naaz, Sk, hello]
#  4262    [We, want, to, read, your, book, sir, ,, pleas...
#  Name: Text, Length: 4263, dtype: object)

# %%
# tk=Tokenizer(filters='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n',lower=True, split=" ")
tk=Tokenizer(lower=True,split=" ")
tk.fit_on_texts(train_line)
word_index=tk.word_index
word_index
# Out:
# {'.': 1,
#  'the': 2,
#  'is': 3,
#  'and': 4,
#  ',': 5,
#  'to': 6,
#  'i': 7,
#  'a': 8,
#  'of': 9,
#  '...': 10,
#  'you': 11,
#  'in': 12,
#  'this': 13,
#  'it': 14,
#  'are': 15,
#  '?': 16,
#  'that': 17,
#  '!': 18,
#  'not': 19,
#  'for': 20,
#  'movie': 21,
#  'like': 22,
#  'but': 23,
#  'on': 24,
#  'be': 25,
#  "n't": 26,
#  "'s": 27,
#  'with': 28,
#  'do': 29,
#  'so': 30,
#  'have': 31,
#  'u': 32,
#  'kabir': 33,
#  'your': 34,
#  'was': 35,
#  'they': 36,
#  'he': 37,
#  'she': 38,
#  'people': 39,
#  'singh': 40,
#  'about': 41,
#  'who': 42,
#  'we': 43,
#  'all': 44,
#  'as': 45,
#  'what': 46,
#  ')': 47,
#  'from': 48,
#  'love': 49,
#  'her': 50,
#  'review': 51,
#  ':': 52,
#  'his': 53,
#  'if': 54,
#  'will': 55,
#  '(': 56,
#  'video': 57,
#  'should': 58,
#  'good': 59,
#  'can': 60,
#  'very': 61,
#  '@': 62,
#  'or': 63,
#  'right': 64,
#  'my': 65,
#  'by': 66,
#  'one': 67,
#  'just': 68,
#  'no': 69,
#  '&': 70,
#  'me': 71,
#  'india': 72,
#  'has': 73,
#  'these': 74,
#  'bro': 75,
#  'nice': 76,
#  'movies': 77,
#  'watch': 78,
#  'why': 79,
#  'their': 80,
#  'man': 81,
#  'sir': 82,
#  'only': 83,
#  'also': 84,
#  'more': 85,
#  'how': 86,
#  'know': 87,
#  'think': 88,
#  'film': 89,
#  'please': 90,
#  'them': 91,
#  'there': 92,
#  'bollywood': 93,
#  'am': 94,
#  'then': 95,
#  "''": 96,
#  'some': 97,
#  'at': 98,
#  'r': 99,
#  'even': 100,
#  'want': 101,
#  'best': 102,
#  'life': 103,
#  '[': 104,
#  ']': 105,
#  'such': 106,
#  'any': 107,
#  'agree': 108,
#  'great': 109,
#  'character': 110,
#  'time': 111,
#  'which': 112,
#  'really': 113,
#  'bhai': 114,
#  'than': 115,
#  'would': 116,
#  'see': 117,
#  'our': 118,
#  'true': 119,
#  'because': 120,
#  'when': 121,
#  'its': 122,
#  'did': 123,
#  'women': 124,
#  'him': 125,
#  'wrong': 126,
#  '``': 127,
#  'well': 128,
#  '..': 129,
#  '%': 130,
#  'girl': 131,
#  'men': 132,
#  'make': 133,
#  'https': 134,
#  '’': 135,
#  'up': 136,
#  'an': 137,
#  'indian': 138,
#  'roy': 139,
#  'way': 140,
#  'feminist': 141,
#  'other': 142,
#  'after': 143,
#  'feminists': 144,
#  'now': 145,
#  'feminism': 146,
#  'get': 147,
#  'real': 148,
#  'out': 149,
#  'does': 150,
#  'same': 151,
#  'say': 152,
#  'need': 153,
#  'said': 154,
#  'story': 155,
#  'arundhati': 156,
#  'take': 157,
#  'here': 158,
#  'too': 159,
#  'much': 160,
#  'every': 161,
#  'person': 162,
#  'ur': 163,
#  'n': 164,
#  'being': 165,
#  'many': 166,
#  'liberals': 167,
#  'point': 168,
#  'give': 169,
#  'thing': 170,
#  'country': 171,
#  'watching': 172,
#  "'m": 173,
#  'god': 174,
#  'guy': 175,
#  'hai': 176,
#  'bad': 177,
#  'gay': 178,
#  'pratik': 179,
#  'most': 180,
#  'where': 181,
#  'never': 182,
#  'problem': 183,
#  'http': 184,
#  'respect': 185,
#  'against': 186,
#  'law': 187,
#  'understand': 188,
#  'always': 189,
#  'those': 190,
#  'support': 191,
#  'arjun': 192,
#  '#': 193,
#  'brother': 194,
#  'ranu': 195,
#  'were': 196,
#  'yes': 197,
#  'go': 198,
#  '-': 199,
#  'made': 200,
#  'totally': 201,
#  'first': 202,
#  '//www.youtube.com/watch': 203,
#  'watched': 204,
#  'woman': 205,
#  'dont': 206,
#  'name': 207,
#  'nothing': 208,
#  'better': 209,
#  'had': 210,
#  't': 211,
#  'ca': 212,
#  'us': 213,
#  'thanks': 214,
#  'reddy': 215,
#  'army': 216,
#  'done': 217,
#  'things': 218,
#  'someone': 219,
#  'sex': 220,
#  'call': 221,
#  'society': 222,
#  'kind': 223,
#  'called': 224,
#  'arnab': 225,
#  "'": 226,
#  'doing': 227,
#  'joker': 228,
#  'shit': 229,
#  'keep': 230,
#  's': 231,
#  'hate': 232,
#  'shahid': 233,
#  'guys': 234,
#  'world': 235,
#  'job': 236,
#  'awesome': 237,
#  '//www.youtube.com/results': 238,
#  'search_query=': 239,
#  'fuck': 240,
#  '>': 241,
#  '<': 242,
#  'over': 243,
#  'come': 244,
#  'been': 245,
#  'stop': 246,
#  'girls': 247,
#  'family': 248,
#  'videos': 249,
#  'making': 250,
#  'acting': 251,
#  'view': 252,
#  'talk': 253,
#  'opinion': 254,
#  'own': 255,
#  'must': 256,
#  'still': 257,
#  'off': 258,
#  'shwetabh': 259,
#  'comment': 260,
#  'm': 261,
#  'without': 262,
#  'channel': 263,
#  'feel': 264,
#  'lot': 265,
#  'before': 266,
#  'seen': 267,
#  'going': 268,
#  'thank': 269,
#  'become': 270,
#  'liberal': 271,
#  'saying': 272,
#  'actually': 273,
#  'debate': 274,
#  'lady': 275,
#  'got': 276,
#  'ever': 277,
#  'male': 278,
#  'let': 279,
#  'wow': 280,
#  'fake': 281,
#  'thought': 282,
#  'big': 283,
#  'hi': 284,
#  'anything': 285,
#  'truth': 286,
#  'characters': 287,
#  'show': 288,
#  'female': 289,
#  'talking': 290,
#  'could': 291,
#  'boy': 292,
#  'toxic': 293,
#  'mind': 294,
#  'money': 295,
#  'both': 296,
#  'hero': 297,
#  '😂': 298,
#  'relationship': 299,
#  'ki': 300,
#  'may': 301,
#  'work': 302,
#  'chutiya': 303,
#  'preeti': 304,
#  'put': 305,
#  'loved': 306,
#  'indians': 307,
#  'father': 308,
#  'message': 309,
#  'live': 310,
#  'everyone': 311,
#  'super': 312,
#  'lesbian': 313,
#  'new': 314,
#  'nation': 315,
#  'violence': 316,
#  'waiting': 317,
#  'end': 318,
#  'govt': 319,
#  'different': 320,
#  'everything': 321,
#  'wife': 322,
#  'case': 323,
#  'mean': 324,
#  'part': 325,
#  'reality': 326,
#  'getting': 327,
#  'views': 328,
#  'shown': 329,
#  'media': 330,
#  'change': 331,
#  'analysis': 332,
#  'false': 333,
#  'again': 334,
#  'look': 335,
#  'face': 336,
#  'stupid': 337,
#  'years': 338,
#  'back': 339,
#  'since': 340,
#  'long': 341,
#  'government': 342,
#  'few': 343,
#  'around': 344,
#  'finally': 345,
#  'negative': 346,
#  'day': 347,
#  "'re": 348,
#  'tell': 349,
#  'boss': 350,
#  'absolutely': 351,
#  'lol': 352,
#  'read': 353,
#  'type': 354,
#  'giving': 355,
#  'having': 356,
#  'honest': 357,
#  'saw': 358,
#  'find': 359,
#  'into': 360,
#  'homosexuality': 361,
#  'films': 362,
#  'trying': 363,
#  'human': 364,
#  'culture': 365,
#  'anyone': 366,
#  'seriously': 367,
#  'means': 368,
#  'shame': 369,
#  'hope': 370,
#  'sense': 371,
#  'speak': 372,
#  'reviews': 373,
#  'says': 374,
#  'something': 375,
#  'v=n_zmfqmzos0': 376,
#  'plz': 377,
#  'police': 378,
#  'marriage': 379,
#  'thinking': 380,
#  'friend': 381,
#  'etc': 382,
#  'liked': 383,
#  '4': 384,
#  'iam': 385,
#  '1': 386,
#  'boys': 387,
#  'homosexual': 388,
#  'wants': 389,
#  'whole': 390,
#  'exactly': 391,
#  'director': 392,
#  'modi': 393,
#  'bitch': 394,
#  'equality': 395,
#  'thoughts': 396,
#  'needs': 397,
#  '2': 398,
#  'word': 399,
#  'others': 400,
#  '100': 401,
#  'don': 402,
#  'else': 403,
#  'left': 404,
#  'fact': 405,
#  'gender': 406,
#  'dog': 407,
#  'fan': 408,
#  'hit': 409,
#  'self': 410,
#  'masculinity': 411,
#  'correct': 412,
#  'main': 413,
#  'perfect': 414,
#  'funny': 415,
#  'pakistan': 416,
#  'dear': 417,
#  'fucking': 418,
#  'anti': 419,
#  'care': 420,
#  'old': 421,
#  'instead': 422,
#  'showing': 423,
#  'amazing': 424,
#  'court': 425,
#  'yourself': 426,
#  'issues': 427,
#  'di': 428,
#  'book': 429,
#  'friends': 430,
#  'social': 431,
#  'parents': 432,
#  'gays': 433,
#  'youtube': 434,
#  'start': 435,
#  'ok': 436,
#  'year': 437,
#  'billa': 438,
#  'today': 439,
#  'shows': 440,
#  'audience': 441,
#  'under': 442,
#  'kasturi': 443,
#  'ranga': 444,
#  'though': 445,
#  'yeah': 446,
#  'two': 447,
#  'public': 448,
#  'away': 449,
#  'completely': 450,
#  'kapoor': 451,
#  'single': 452,
#  'behind': 453,
#  'crime': 454,
#  'act': 455,
#  'happy': 456,
#  'south': 457,
#  'rather': 458,
#  'far': 459,
#  'sexual': 460,
#  'sorry': 461,
#  'd': 462,
#  'superb': 463,
#  'youth': 464,
#  'bjp': 465,
#  'generation': 466,
#  'garbage': 467,
#  'words': 468,
#  'appreciate': 469,
#  'freedom': 470,
#  'learn': 471,
#  '👍': 472,
#  'leave': 473,
#  'home': 474,
#  'looks': 475,
#  'salute': 476,
#  'lgbt': 477,
#  'try': 478,
#  'proud': 479,
#  '498a': 480,
#  'ye': 481,
#  "'ll": 482,
#  'ko': 483,
#  'allowed': 484,
#  'free': 485,
#  'wanted': 486,
#  'follow': 487,
#  'based': 488,
#  'already': 489,
#  'dude': 490,
#  'given': 491,
#  'days': 492,
#  'yet': 493,
#  'likes': 494,
#  'speaking': 495,
#  'top': 496,
#  'side': 497,
#  'realistic': 498,
#  'pls': 499,
#  'coz': 500,
#  'believe': 501,
#  'reason': 502,
#  'whatever': 503,
#  'english': 504,
#  'nature': 505,
#  'thats': 506,
#  'abuse': 507,
#  'lost': 508,
#  'next': 509,
#  'hindi': 510,
#  'speech': 511,
#  'shots': 512,
#  'ji': 513,
#  'points': 514,
#  'nd': 515,
#  'se': 516,
#  'biggest': 517,
#  'comes': 518,
#  'mental': 519,
#  'sucharita': 520,
#  'scene': 521,
#  'help': 522,
#  'dada': 523,
#  'reply': 524,
#  'sure': 525,
#  '10': 526,
#  '3': 527,
#  'rape': 528,
#  'bhi': 529,
#  'last': 530,
#  'ke': 531,
#  'created': 532,
#  'took': 533,
#  'worst': 534,
#  'genuine': 535,
#  'shitty': 536,
#  'bring': 537,
#  'telling': 538,
#  'number': 539,
#  'literally': 540,
#  'news': 541,
#  'husband': 542,
#  'atleast': 543,
#  'themselves': 544,
#  'system': 545,
#  'laws': 546,
#  'opinions': 547,
#  'once': 548,
#  'industry': 549,
#  'hollywood': 550,
#  'simple': 551,
#  'beautiful': 552,
#  'anger': 553,
#  'kumar': 554,
#  'ask': 555,
#  'changed': 556,
#  'makes': 557,
#  'domestic': 558,
#  'towards': 559,
#  'place': 560,
#  'mad': 561,
#  'used': 562,
#  'born': 563,
#  'hello': 564,
#  'attitude': 565,
#  'send': 566,
#  'seems': 567,
#  'topic': 568,
#  'accept': 569,
#  'times': 570,
#  'hell': 571,
#  'poor': 572,
#  'ho': 573,
#  'agenda': 574,
#  'personal': 575,
#  'came': 576,
#  'wedding': 577,
#  'positive': 578,
#  'open': 579,
#  'sad': 580,
#  'ka': 581,
#  'each': 582,
#  'action': 583,
#  'enjoy': 584,
#  'waste': 585,
#  'ppl': 586,
#  'nrc': 587,
#  'situation': 588,
#  'dumb': 589,
#  'share': 590,
#  'according': 591,
#  'bullshit': 592,
#  'future': 593,
#  'deserve': 594,
#  'perspective': 595,
#  'rights': 596,
#  'legal': 597,
#  'kya': 598,
#  'nupur': 599,
#  '😂😂': 600,
#  'control': 601,
#  'full': 602,
#  'content': 603,
#  'started': 604,
#  'borade': 605,
#  'songs': 606,
#  'pseudo': 607,
#  'looking': 608,
#  '👌': 609,
#  'another': 610,
#  '5': 611,
#  'bt': 612,
#  'taken': 613,
#  'nailed': 614,
#  'told': 615,
#  'idea': 616,
#  'state': 617,
#  'arrest': 618,
#  'coming': 619,
#  'line': 620,
#  'issue': 621,
#  'stand': 622,
#  'till': 623,
#  'journalist': 624,
#  'answer': 625,
#  'jahangir': 626,
#  'doctor': 627,
#  'drugs': 628,
#  'b': 629,
#  'problems': 630,
#  'equal': 631,
#  'agreed': 632,
#  'knew': 633,
#  'between': 634,
#  'alcohol': 635,
#  'might': 636,
#  'jail': 637,
#  'hindu': 638,
#  'na': 639,
#  'gives': 640,
#  'national': 641,
#  'behavior': 642,
#  'high': 643,
#  'down': 644,
#  'during': 645,
#  'nonsense': 646,
#  'married': 647,
#  'shut': 648,
#  'actors': 649,
#  'actor': 650,
#  'abusive': 651,
#  'meaning': 652,
#  'sister': 653,
#  'section': 654,
#  'least': 655,
#  'sandeep': 656,
#  'npr': 657,
#  'enough': 658,
#  'use': 659,
#  'otherwise': 660,
#  'due': 661,
#  'wish': 662,
#  'political': 663,
#  'immediately': 664,
#  'slap': 665,
#  'fight': 666,
#  'felt': 667,
#  'bless': 668,
#  'became': 669,
#  'song': 670,
#  'consent': 671,
#  'less': 672,
#  'stories': 673,
#  '😍': 674,
#  'body': 675,
#  'dislikes': 676,
#  'especially': 677,
#  'rajdeep': 678,
#  'through': 679,
#  '377': 680,
#  'level': 681,
#  '30': 682,
#  'multiple': 683,
#  'needed': 684,
#  'concept': 685,
#  'information': 686,
#  'trailer': 687,
#  'movie..': 688,
#  'khan': 689,
#  'mondal': 690,
#  'wo': 691,
#  'didnt': 692,
#  'while': 693,
#  'slapped': 694,
#  'kutta': 695,
#  'cases': 696,
#  'damn': 697,
#  'population': 698,
#  'nahi': 699,
#  'non': 700,
#  'clear': 701,
#  'cant': 702,
#  'using': 703,
#  'companion': 704,
#  'caa': 705,
#  'explanation': 706,
#  'bloody': 707,
#  'western': 708,
#  'age': 709,
#  'bit': 710,
#  'loves': 711,
#  'ones': 712,
#  'natural': 713,
#  'normal': 714,
#  '.i': 715,
#  'v': 716,
#  'aur': 717,
#  'hii': 718,
#  'innocent': 719,
#  'taking': 720,
#  'college': 721,
#  'hindus': 722,
#  'emotions': 723,
#  'impact': 724,
#  'choice': 725,
#  'de': 726,
#  'drinking': 727,
#  'oh': 728,
#  'understanding': 729,
#  'serious': 730,
#  'actions': 731,
#  'living': 732,
#  'study': 733,
#  'imagine': 734,
#  'gave': 735,
#  'four': 736,
#  'except': 737,
#  'voice': 738,
#  'veere': 739,
#  'fu': 740,
#  'msg': 741,
#  'medical': 742,
#  'congress': 743,
#  'cool': 744,
#  'lesbians': 745,
#  '😂😂😂': 746,
#  'ar': 747,
#  'starts': 748,
#  'mouth': 749,
#  'intellectual': 750,
#  'dangerous': 751,
#  'lots': 752,
#  'scenes': 753,
#  'personality': 754,
#  'night': 755,
#  'whatsapp': 756,
#  'hard': 757,
#  'almost': 758,
#  'arrested': 759,
#  'urban': 760,
#  'lives': 761,
#  'wonder': 762,
#  'lead': 763,
#  'hear': 764,
#  'openly': 765,
#  'regarding': 766,
#  'happen': 767,
#  'emotional': 768,
#  'pure': 769,
#  'knows': 770,
#  'dowry': 771,
#  'anchor': 772,
#  'physical': 773,
#  'language': 774,
#  'misleading': 775,
#  'break': 776,
#  'hand': 777,
#  'im': 778,
#  'little': 779,
#  'sick': 780,
#  'truly': 781,
#  'values': 782,
#  'telugu': 783,
#  'listen': 784,
#  'behaviour': 785,
#  'heart': 786,
#  'logic': 787,
#  'personally': 788,
#  'religion': 789,
#  'omg': 790,
#  'found': 791,
#  'request': 792,
#  'ideas': 793,
#  'following': 794,
#  '🤣': 795,
#  'education': 796,
#  '🙏': 797,
#  'kung': 798,
#  'tyagi': 799,
#  'ignorant': 800,
#  'series': 801,
#  'feeling': 802,
#  'f': 803,
#  'hot': 804,
#  'direction': 805,
#  'possible': 806,
#  'interested': 807,
#  'l': 808,
#  'disgusting': 809,
#  'lies': 810,
#  'homosexuals': 811,
#  'destroy': 812,
#  'minded': 813,
#  'soon': 814,
#  '🔥': 815,
#  'asked': 816,
#  'spreading': 817,
#  'inside': 818,
#  'happened': 819,
#  'cancer': 820,
#  'h': 821,
#  'straight': 822,
#  'whether': 823,
#  'bible': 824,
#  'able': 825,
#  'power': 826,
#  'justify': 827,
#  'flawed': 828,
#  'earth': 829,
#  'constitution': 830,
#  'ek': 831,
#  '=': 832,
#  'expect': 833,
#  'entire': 834,
#  'released': 835,
#  'anime': 836,
#  'half': 837,
#  'idiot': 838,
#  'typical': 839,
#  'knowledge': 840,
#  'silent': 841,
#  '😂😂😂😂': 842,
#  'nobody': 843,
#  'influenced': 844,
#  'takes': 845,
#  'common': 846,
#  'peace': 847,
#  'matter': 848,
#  'pm': 849,
#  'tv': 850,
#  'citizens': 851,
#  'myself': 852,
#  'modern': 853,
#  'hated': 854,
#  'mentally': 855,
#  'class': 856,
#  'supporting': 857,
#  'leftist': 858,
#  'v=j2j5sssp5yq': 859,
#  '💯': 860,
#  'arundati': 861,
#  'bangladesh': 862,
#  'guess': 863,
#  'destroyed': 864,
#  'eye': 865,
#  'destructive': 866,
#  'order': 867,
#  'dark': 868,
#  "don't": 869,
#  'either': 870,
#  'partner': 871,
#  'run': 872,
#  'suffer': 873,
#  'basic': 874,
#  'huge': 875,
#  'promote': 876,
#  'shirt': 877,
#  'rest': 878,
#  'check': 879,
#  'kill': 880,
#  'drink': 881,
#  'comments': 882,
#  'gets': 883,
#  'sharma': 884,
#  'entertainment': 885,
#  'stay': 886,
#  'tere': 887,
#  'naam': 888,
#  'nyc': 889,
#  'ugly': 890,
#  'criminal': 891,
#  'fun': 892,
#  'responsibility': 893,
#  'supreme': 894,
#  'course': 895,
#  'hain': 896,
#  'whom': 897,
#  'lie': 898,
#  'depends': 899,
#  'mandal': 900,
#  'difference': 901,
#  'tried': 902,
#  'profession': 903,
#  'stuff': 904,
#  'war': 905,
#  'glorifying': 906,
#  'random': 907,
#  'inspired': 908,
#  'husbands': 909,
#  'young': 910,
#  'judge': 911,
#  'explain': 912,
#  '😊': 913,
#  'short': 914,
#  'mondol': 915,
#  'quite': 916,
#  'raw': 917,
#  'ready': 918,
#  'role': 919,
#  'luck': 920,
#  '--': 921,
#  'blockbuster': 922,
#  'alone': 923,
#  'debates': 924,
#  'jai': 925,
#  'spoiler': 926,
#  'write': 927,
#  'form': 928,
#  'paid': 929,
#  'mensutra': 930,
#  'group': 931,
#  'addict': 932,
#  'masterpiece': 933,
#  'bed': 934,
#  'child': 935,
#  'actual': 936,
#  'dis': 937,
#  'vanga': 938,
#  'seeing': 939,
#  '20': 940,
#  'crap': 941,
#  'banned': 942,
#  'countries': 943,
#  'excellent': 944,
#  'illiterate': 945,
#  'step': 946,
#  'stopped': 947,
#  'rule': 948,
#  'remember': 949,
#  '🤣🤣🤣': 950,
#  'fall': 951,
#  'hey': 952,
#  'blood': 953,
#  'question': 954,
#  'killing': 955,
#  'killed': 956,
#  'politics': 957,
#  'basically': 958,
#  'bc': 959,
#  'grow': 960,
#  'fault': 961,
#  'birth': 962,
#  'house': 963,
#  'everybody': 964,
#  'harsh': 965,
#  'expose': 966,
#  'affect': 967,
#  'opposite': 968,
#  'save': 969,
#  "'ve": 970,
#  'mother': 971,
#  'showed': 972,
#  'ago': 973,
#  'shouting': 974,
#  'k': 975,
#  'working': 976,
#  'prostitute': 977,
#  'yaar': 978,
#  'idiots': 979,
#  'biased': 980,
#  'play': 981,
#  'himself': 982,
#  'putting': 983,
#  'black': 984,
#  'g': 985,
#  'tha': 986,
#  'death': 987,
#  'feelings': 988,
#  'promoting': 989,
#  'cinema': 990,
#  'defend': 991,
#  '15': 992,
#  'music': 993,
#  'tells': 994,
#  'explained': 995,
#  'spread': 996,
#  'nhi': 997,
#  'complete': 998,
#  'randi': 999,
#  'moral': 1000,
#  ...}

# %%
import math
length=math.ceil(np.average(train_line.apply(lambda x:len(x))))
length
# Out:
# 20

# %%
def encode_text(tokenizer, lines, length):
  encoded = tokenizer.texts_to_sequences(lines)
  padded = pad_sequences(encoded, maxlen=length, padding='post')
  return padded

# %%
train_x=encode_text(tk,train_line,20)
print(train_x)
dev_x=encode_text(tk,dev_line,20)
print(dev_x)
# Out:
# [[  509   325     0 ...     0     0     0]
#  [ 3983  3984     0 ...     0     0     0]
#  [ 3985  1002    10 ...     0     0     0]
#  ...
#  [    6  1196   503 ... 10368   470    18]
#  [   62 10369 10370 ...     0     0     0]
#  [   43   101     6 ...     0     0     0]]
# [[ 32 594  85 ...   0   0   0]
#  [ 76  57  10 ...   0   0   0]
#  [ 56 112   3 ... 672  92  10]
#  ...
#  [ 49  32  75 ...   0   0   0]
#  [301   7 522 ...   0   0   0]
#  [ 82  18  18 ...  95   2  21]]

# %%
vocab_size = len(tk.word_index)
print(vocab_size)
# Out:
# 10370

# %%
# from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(padded_docs, y, test_size=0.30, random_state=42)

# %%
#load pre-trained embedding:
zip_ref = zipfile.ZipFile("/content/drive/My Drive/crawl-300d-2M.vec.zip", 'r')
zip_ref.extractall()
zip_ref.close()
embeddings_index = {}
f = open('/content/crawl-300d-2M.vec', encoding="utf8")
for line in f:
    values = line.split()#This splits each values in a  line with spaces
    word = values[0] # This store the first values which is the word in english
    coefs = np.asarray(values[1:], dtype='float32') # This converts all splitted values from 1 to last(expect first word) into an array
    embeddings_index[word] = coefs # english word = array of numerical values
f.close()
print('Total %s word vectors in crawl-300-2M.' % len(embeddings_index))
# Out:
# Total 1999996 word vectors in crawl-300-2M.

# %%
embeddings_index['🤣'].shape
# Out:
# (300,)

# %%
# Initialize the weight for each word for the embedding layer. Words not present
# in the dictionary initialized by random value 
EMBEDDING_DIM = 300
embedding_matrix = np.random.random((len(word_index) + 1, EMBEDDING_DIM))
#embedding_matrix = (10370, 300) NOTE: It is from uniques words in our tweets
for word, i in word_index.items(): # Selecting word from our tweet unique words list for changing with the values from glove
    embedding_vector = embeddings_index.get(word) # Finding our tweet words in glove and taking its array of 100 values
    if embedding_vector is not None: 
#words not found in embedding index will be all-zeros.
        embedding_matrix[i] = embedding_vector

# %%
y_train=np.array(train_df['Sub-task B'])
y_dev=np.array(dev_df['Sub-task B'])

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Embedding
from keras.layers import Conv1D, GlobalMaxPooling1D, MaxPooling1D
from keras.utils.vis_utils import plot_model
model = Sequential()
model.add(Embedding(input_dim = vocab_size + 1, output_dim = 300, weights=[embedding_matrix], input_length=length,trainable=False))
model.add(Conv1D(filters = 128,kernel_size=3, activation='relu'))
model.add(MaxPooling1D(5))
model.add(Dropout(0.5))
model.add(Flatten())
model.add(Dense(256, activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation = 'sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='Adam', metrics=['accuracy'])
model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_4 (Embedding)      (None, 20, 300)           3111300
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 18, 128)           115328
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 3, 128)            0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 3, 128)            0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 384)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 256)               98560
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 3,325,445
# Trainable params: 214,145
# Non-trainable params: 3,111,300
# _________________________________________________________________

# %%
history=model.fit(train_x, y_train, validation_data = (dev_x, y_dev),epochs=100,batch_size=100, verbose=2)
# Out:
# Train on 4263 samples, validate on 1066 samples
# Epoch 1/100
#  - 0s - loss: 0.0053 - acc: 0.9984 - val_loss: 0.7148 - val_acc: 0.9325
# Epoch 2/100
#  - 0s - loss: 0.0093 - acc: 0.9972 - val_loss: 0.6823 - val_acc: 0.9353
# Epoch 3/100
#  - 0s - loss: 0.0048 - acc: 0.9988 - val_loss: 0.6589 - val_acc: 0.9353
# Epoch 4/100
#  - 0s - loss: 0.0097 - acc: 0.9984 - val_loss: 0.6980 - val_acc: 0.9325
# Epoch 5/100
#  - 0s - loss: 0.0062 - acc: 0.9981 - val_loss: 0.6712 - val_acc: 0.9343
# Epoch 6/100
#  - 0s - loss: 0.0035 - acc: 0.9984 - val_loss: 0.7208 - val_acc: 0.9343
# Epoch 7/100
#  - 0s - loss: 0.0042 - acc: 0.9984 - val_loss: 0.6886 - val_acc: 0.9362
# Epoch 8/100
#  - 0s - loss: 0.0024 - acc: 0.9993 - val_loss: 0.7909 - val_acc: 0.9353
# Epoch 9/100
#  - 0s - loss: 0.0051 - acc: 0.9984 - val_loss: 0.7254 - val_acc: 0.9353
# Epoch 10/100
#  - 0s - loss: 0.0049 - acc: 0.9986 - val_loss: 0.6814 - val_acc: 0.9315
# Epoch 11/100
#  - 0s - loss: 0.0077 - acc: 0.9981 - val_loss: 0.7665 - val_acc: 0.9325
# Epoch 12/100
#  - 0s - loss: 0.0052 - acc: 0.9988 - val_loss: 0.8028 - val_acc: 0.9315
# Epoch 13/100
#  - 0s - loss: 0.0093 - acc: 0.9981 - val_loss: 0.6625 - val_acc: 0.9371
# Epoch 14/100
#  - 0s - loss: 0.0062 - acc: 0.9986 - val_loss: 0.7478 - val_acc: 0.9343
# Epoch 15/100
#  - 0s - loss: 0.0095 - acc: 0.9974 - val_loss: 0.6554 - val_acc: 0.9362
# Epoch 16/100
#  - 0s - loss: 0.0084 - acc: 0.9974 - val_loss: 0.6576 - val_acc: 0.9353
# Epoch 17/100
#  - 0s - loss: 0.0092 - acc: 0.9984 - val_loss: 0.6377 - val_acc: 0.9343
# Epoch 18/100
#  - 0s - loss: 0.0042 - acc: 0.9986 - val_loss: 0.6260 - val_acc: 0.9353
# Epoch 19/100
#  - 0s - loss: 0.0045 - acc: 0.9986 - val_loss: 0.7072 - val_acc: 0.9353
# Epoch 20/100
#  - 0s - loss: 0.0053 - acc: 0.9979 - val_loss: 0.6993 - val_acc: 0.9334
# Epoch 21/100
#  - 0s - loss: 0.0078 - acc: 0.9974 - val_loss: 0.7237 - val_acc: 0.9325
# Epoch 22/100
#  - 0s - loss: 0.0117 - acc: 0.9977 - val_loss: 0.6903 - val_acc: 0.9334
# Epoch 23/100
#  - 0s - loss: 0.0045 - acc: 0.9988 - val_loss: 0.6928 - val_acc: 0.9315
# Epoch 24/100
#  - 0s - loss: 0.0052 - acc: 0.9986 - val_loss: 0.7408 - val_acc: 0.9325
# Epoch 25/100
#  - 0s - loss: 0.0056 - acc: 0.9984 - val_loss: 0.6810 - val_acc: 0.9315
# Epoch 26/100
#  - 0s - loss: 0.0052 - acc: 0.9988 - val_loss: 0.7354 - val_acc: 0.9315
# Epoch 27/100
#  - 0s - loss: 0.0070 - acc: 0.9984 - val_loss: 0.7960 - val_acc: 0.9315
# Epoch 28/100
#  - 0s - loss: 0.0048 - acc: 0.9981 - val_loss: 0.7377 - val_acc: 0.9343
# Epoch 29/100
#  - 0s - loss: 0.0078 - acc: 0.9979 - val_loss: 0.7790 - val_acc: 0.9325
# Epoch 30/100
#  - 0s - loss: 0.0080 - acc: 0.9984 - val_loss: 0.6773 - val_acc: 0.9334
# Epoch 31/100
#  - 0s - loss: 0.0065 - acc: 0.9984 - val_loss: 0.6933 - val_acc: 0.9325
# Epoch 32/100
#  - 0s - loss: 0.0059 - acc: 0.9984 - val_loss: 0.6581 - val_acc: 0.9306
# Epoch 33/100
#  - 0s - loss: 0.0101 - acc: 0.9970 - val_loss: 0.7286 - val_acc: 0.9306
# Epoch 34/100
#  - 0s - loss: 0.0068 - acc: 0.9984 - val_loss: 0.7541 - val_acc: 0.9353
# Epoch 35/100
#  - 0s - loss: 0.0061 - acc: 0.9977 - val_loss: 0.6717 - val_acc: 0.9315
# Epoch 36/100
#  - 0s - loss: 0.0041 - acc: 0.9984 - val_loss: 0.7020 - val_acc: 0.9315
# Epoch 37/100
#  - 0s - loss: 0.0094 - acc: 0.9970 - val_loss: 0.6895 - val_acc: 0.9268
# Epoch 38/100
#  - 0s - loss: 0.0057 - acc: 0.9986 - val_loss: 0.7813 - val_acc: 0.9325
# Epoch 39/100
#  - 0s - loss: 0.0089 - acc: 0.9981 - val_loss: 0.6720 - val_acc: 0.9221
# Epoch 40/100
#  - 0s - loss: 0.0073 - acc: 0.9984 - val_loss: 0.7918 - val_acc: 0.9306
# Epoch 41/100
#  - 0s - loss: 0.0028 - acc: 0.9995 - val_loss: 0.8004 - val_acc: 0.9315
# Epoch 42/100
#  - 0s - loss: 0.0065 - acc: 0.9979 - val_loss: 0.7702 - val_acc: 0.9325
# Epoch 43/100
#  - 0s - loss: 0.0069 - acc: 0.9986 - val_loss: 0.7876 - val_acc: 0.9334
# Epoch 44/100
#  - 0s - loss: 0.0074 - acc: 0.9984 - val_loss: 0.6720 - val_acc: 0.9306
# Epoch 45/100
#  - 0s - loss: 0.0048 - acc: 0.9988 - val_loss: 0.6976 - val_acc: 0.9287
# Epoch 46/100
#  - 0s - loss: 0.0075 - acc: 0.9977 - val_loss: 0.7858 - val_acc: 0.9315
# Epoch 47/100
#  - 0s - loss: 0.0103 - acc: 0.9974 - val_loss: 0.7337 - val_acc: 0.9325
# Epoch 48/100
#  - 0s - loss: 0.0115 - acc: 0.9960 - val_loss: 0.6933 - val_acc: 0.9334
# Epoch 49/100
#  - 0s - loss: 0.0157 - acc: 0.9970 - val_loss: 0.6732 - val_acc: 0.9306
# Epoch 50/100
#  - 0s - loss: 0.0089 - acc: 0.9974 - val_loss: 0.7120 - val_acc: 0.9306
# Epoch 51/100
#  - 0s - loss: 0.0042 - acc: 0.9988 - val_loss: 0.7266 - val_acc: 0.9343
# Epoch 52/100
#  - 0s - loss: 0.0085 - acc: 0.9974 - val_loss: 0.7389 - val_acc: 0.9306
# Epoch 53/100
#  - 0s - loss: 0.0050 - acc: 0.9986 - val_loss: 0.7110 - val_acc: 0.9315
# Epoch 54/100
#  - 0s - loss: 0.0034 - acc: 0.9993 - val_loss: 0.6908 - val_acc: 0.9334
# Epoch 55/100
#  - 0s - loss: 0.0062 - acc: 0.9984 - val_loss: 0.6955 - val_acc: 0.9325
# Epoch 56/100
#  - 0s - loss: 0.0061 - acc: 0.9979 - val_loss: 0.7017 - val_acc: 0.9343
# Epoch 57/100
#  - 0s - loss: 0.0072 - acc: 0.9981 - val_loss: 0.7393 - val_acc: 0.9315
# Epoch 58/100
#  - 0s - loss: 0.0054 - acc: 0.9988 - val_loss: 0.6899 - val_acc: 0.9325
# Epoch 59/100
#  - 0s - loss: 0.0044 - acc: 0.9986 - val_loss: 0.7202 - val_acc: 0.9306
# Epoch 60/100
#  - 0s - loss: 0.0059 - acc: 0.9986 - val_loss: 0.7241 - val_acc: 0.9296
# Epoch 61/100
#  - 0s - loss: 0.0059 - acc: 0.9986 - val_loss: 0.7097 - val_acc: 0.9287
# Epoch 62/100
#  - 0s - loss: 0.0072 - acc: 0.9979 - val_loss: 0.7498 - val_acc: 0.9334
# Epoch 63/100
#  - 0s - loss: 0.0043 - acc: 0.9988 - val_loss: 0.7724 - val_acc: 0.9325
# Epoch 64/100
#  - 0s - loss: 0.0085 - acc: 0.9974 - val_loss: 0.6989 - val_acc: 0.9334
# Epoch 65/100
#  - 0s - loss: 0.0076 - acc: 0.9974 - val_loss: 0.7527 - val_acc: 0.9315
# Epoch 66/100
#  - 0s - loss: 0.0077 - acc: 0.9977 - val_loss: 0.7353 - val_acc: 0.9343
# Epoch 67/100
#  - 0s - loss: 0.0093 - acc: 0.9981 - val_loss: 0.7288 - val_acc: 0.9334
# Epoch 68/100
#  - 0s - loss: 0.0047 - acc: 0.9986 - val_loss: 0.7011 - val_acc: 0.9315
# Epoch 69/100
#  - 0s - loss: 0.0062 - acc: 0.9981 - val_loss: 0.7569 - val_acc: 0.9315
# Epoch 70/100
#  - 0s - loss: 0.0046 - acc: 0.9986 - val_loss: 0.7652 - val_acc: 0.9306
# Epoch 71/100
#  - 0s - loss: 0.0035 - acc: 0.9991 - val_loss: 0.8539 - val_acc: 0.9296
# Epoch 72/100
#  - 0s - loss: 0.0049 - acc: 0.9991 - val_loss: 0.7632 - val_acc: 0.9287
# Epoch 73/100
#  - 0s - loss: 0.0014 - acc: 1.0000 - val_loss: 0.8137 - val_acc: 0.9334
# Epoch 74/100
#  - 0s - loss: 0.0068 - acc: 0.9986 - val_loss: 0.8140 - val_acc: 0.9334
# Epoch 75/100
#  - 0s - loss: 0.0048 - acc: 0.9986 - val_loss: 0.7691 - val_acc: 0.9306
# Epoch 76/100
#  - 0s - loss: 0.0070 - acc: 0.9981 - val_loss: 0.6975 - val_acc: 0.9306
# Epoch 77/100
#  - 0s - loss: 0.0027 - acc: 0.9988 - val_loss: 0.8127 - val_acc: 0.9343
# Epoch 78/100
#  - 0s - loss: 0.0091 - acc: 0.9981 - val_loss: 0.7563 - val_acc: 0.9325
# Epoch 79/100
#  - 0s - loss: 0.0041 - acc: 0.9986 - val_loss: 0.7531 - val_acc: 0.9325
# Epoch 80/100
#  - 0s - loss: 0.0040 - acc: 0.9986 - val_loss: 0.8142 - val_acc: 0.9315
# Epoch 81/100
#  - 0s - loss: 0.0031 - acc: 0.9986 - val_loss: 0.8226 - val_acc: 0.9306
# Epoch 82/100
#  - 0s - loss: 0.0053 - acc: 0.9986 - val_loss: 0.7632 - val_acc: 0.9306
# Epoch 83/100
#  - 0s - loss: 0.0107 - acc: 0.9977 - val_loss: 0.7142 - val_acc: 0.9325
# Epoch 84/100
#  - 0s - loss: 0.0091 - acc: 0.9979 - val_loss: 0.7688 - val_acc: 0.9325
# Epoch 85/100
#  - 0s - loss: 0.0047 - acc: 0.9988 - val_loss: 0.7368 - val_acc: 0.9334
# Epoch 86/100
#  - 0s - loss: 0.0029 - acc: 0.9995 - val_loss: 0.7556 - val_acc: 0.9315
# Epoch 87/100
#  - 0s - loss: 0.0027 - acc: 0.9993 - val_loss: 0.7555 - val_acc: 0.9306
# Epoch 88/100
#  - 0s - loss: 0.0027 - acc: 0.9995 - val_loss: 0.7844 - val_acc: 0.9306
# Epoch 89/100
#  - 0s - loss: 0.0071 - acc: 0.9984 - val_loss: 0.7768 - val_acc: 0.9334
# Epoch 90/100
#  - 0s - loss: 0.0058 - acc: 0.9986 - val_loss: 0.7565 - val_acc: 0.9343
# Epoch 91/100
#  - 0s - loss: 0.0038 - acc: 0.9991 - val_loss: 0.7899 - val_acc: 0.9334
# Epoch 92/100
#  - 0s - loss: 0.0029 - acc: 0.9991 - val_loss: 0.8495 - val_acc: 0.9315
# Epoch 93/100
#  - 0s - loss: 0.0088 - acc: 0.9981 - val_loss: 0.8164 - val_acc: 0.9315
# Epoch 94/100
#  - 0s - loss: 0.0075 - acc: 0.9984 - val_loss: 0.7388 - val_acc: 0.9343
# Epoch 95/100
#  - 0s - loss: 0.0073 - acc: 0.9981 - val_loss: 0.7697 - val_acc: 0.9325
# Epoch 96/100
#  - 0s - loss: 0.0083 - acc: 0.9981 - val_loss: 0.7347 - val_acc: 0.9334
# Epoch 97/100
#  - 0s - loss: 0.0035 - acc: 0.9993 - val_loss: 0.7586 - val_acc: 0.9325
# Epoch 98/100
#  - 0s - loss: 0.0036 - acc: 0.9993 - val_loss: 0.7623 - val_acc: 0.9325
# Epoch 99/100
#  - 0s - loss: 0.0040 - acc: 0.9991 - val_loss: 0.7544 - val_acc: 0.9325
# Epoch 100/100
#  - 0s - loss: 0.0077 - acc: 0.9977 - val_loss: 0.7286 - val_acc: 0.9334

# %%
plot_model(model)

# %%
training_loss=history.history['loss']
validation_loss=history.history['val_loss']
epoch_count=range(1,len(training_loss)+1)
plt.plot(epoch_count, training_loss, 'r--')
plt.plot(epoch_count, validation_loss, 'b-')
plt.legend(['Training Loss', 'Validation Loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
scores = model.evaluate(dev_x, y_dev, verbose=0)
print(scores)
# Out:
# [0.7286283324056143, 0.9333958724202627]

# %%
model.save('my_model.h5')

# %%
yhat=model.predict(dev_x,batch_size=100,verbose=1,use_multiprocessing=True)
yhat=(yhat>=0.5).astype(int)
tdf=pd.DataFrame(yhat).rename(columns={0:'Prediction'})
tdf.to_csv("op.csv")
tdf
# Out:
# 1066/1066 [==============================] - 0s 96us/step
#       Prediction
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 1061           0
# 1062           0
# 1063           0
# 1064           0
# 1065           0
#
# [1066 rows x 1 columns]

# %%
m=confusion_matrix(y_pred=yhat, y_true=y_dev, labels=[1,0])
nm=confusion_matrix(y_pred=yhat, y_true=y_dev, labels=[1,0],normalize='true')
print(m)
print(nm)
# Out:
# [[ 13  60]
#  [ 11 982]]
# [[0.17808219 0.82191781]
#  [0.01107754 0.98892246]]

# %%
fig=plt.figure().add_subplot()
fig.matshow(m)

# %%
print(sklearn.metrics.classification_report(y_dev, yhat, labels=[0, 1]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97       993
#            1       0.54      0.18      0.27        73
#
#     accuracy                           0.93      1066
#    macro avg       0.74      0.58      0.62      1066
# weighted avg       0.91      0.93      0.92      1066
